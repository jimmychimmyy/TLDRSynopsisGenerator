# %%
import numpy as np
import pandas as pd
import os
import re
import math
import random

from gensim.summarization import summarize

# %% [markdown]
# ## Load datasets

# %%
# load datasets
data_path = 'data.csv'
df = pd.read_csv(data_path, sep='\t', encoding='utf-8')
print('total instances from original dataset:', df.shape[0])
# Out:
# total instances from original dataset: 32834

# %% [markdown]
# ## Clean dataset
#
# TODO: delete anything that starts with backslash \\[a-z]

# %%
# strip first plot synopsis from each synopsis
df['Synopsis'] = df['Synopsis'].str.replace(r'\[|\]|\'|\.|\"', '')
df['Synopsis'] = df['Synopsis'].str.split(':').str[0]
df['Synopsis'] = df['Synopsis'].str.lower()

# make everything lowercase
df['MovieTitle'] = df['MovieTitle'].str.lower()
df['MoviePlot'] = df['MoviePlot'].str.lower()

# clean movie plots
#df['MoviePlot'] = df['MoviePlot'].str.replace(r'\{{\w+}} |\{{\w+\ \w+\}} ', '')
#df['MoviePlot'] = df['MoviePlot'].str.replace(r' :|\= |\"|;|:|#', '')

df['MoviePlot'] = df['MoviePlot'].str.replace("-", " ")
df['Synopsis'] = df['Synopsis'].str.replace("-", " ")

df['MoviePlot'] = df['MoviePlot'].str.replace(r"[^a-z0-9,.\ ]", "")
df['MoviePlot'] = df['MoviePlot'].str.replace(r'\s+([?.!,"\ ])', r'\1')
df['MoviePlot'] = df['MoviePlot'].str.strip()

df['Synopsis'] = df['Synopsis'].str.replace(r"[^a-z0-9,.\ ]", "")
df['Synopsis'] = df['Synopsis'].str.replace(r'\s+([?.!,"\ ])', r'\1')
df['Synopsis'] = df['Synopsis'].str.strip()

df = df[~df['MoviePlot'].str.contains("http")]

# keep only synopsis where len < 280 chars
# synopsis must be longer than 25 chars
# movie plots must be 280 chars or more
MAX_LEN = 5000
MAX_LEN_SYNOPSIS = 280
MIN_LEN_SYNOPSIS = 25
df = df[df['Synopsis'].str.len() < MAX_LEN_SYNOPSIS]
df = df[df['Synopsis'].str.len() > MIN_LEN_SYNOPSIS]
df = df[df['MoviePlot'].str.len() < MAX_LEN]
df = df[df['MoviePlot'].str.len() > MAX_LEN_SYNOPSIS]

df.head(25)
# Out:
#     MovieId                         MovieTitle  Year  \
# 0      3217                   army of darkness  1992
# 2      3746                       blade runner  1982
# 5      4227                       barry lyndon  1975
# 6      4231           buffy the vampire slayer  1992
# 7      4560                         braveheart  1995
# 8      4726                             batman  1989
# 9      4727                             batman  1966
# 10     4728                     batman returns  1992
# 11     4729                     batman & robin  1997
# 12     4730                     batman forever  1995
# 13     5224                       citizen kane  1941
# 14     5313     crouching tiger, hidden dragon  2000
# 15     5729                   chariots of fire  1981
# 16     7906                 destry rides again  1939
# 17     8481                    dressed to kill  1980
# 19     8994                           das boot  1981
# 20     9294                      the evil dead  1981
# 21     9429                 young and innocent  1937
# 22     9835               escape from new york  1981
# 25    10487                       evil dead ii  1987
# 26    10977                           fearless  1993
# 27    11167                flåklypa grand prix  1975
# 29    11242  final fantasy: the spirits within  2001
# 30    11585                       show me love  1998
# 31    11701                  full metal jacket  1987
#
#                                             MoviePlot  \
# 0   after being pulled through a time portal, ash ...
# 2   hatnote in los angeles, november 2019, retired...
# 5   by what means redmond barry acquired the style...
# 6   buffy summers is introduced as a stereotypical...
# 7   in the 13th century, after several years of po...
# 8   as a child, bruce wayne witnesses his parents ...
# 9   when batman and robin get a tip that commodore...
# 10  a deformed baby boy is thrown into gotham city...
# 11  in gotham city, batman and robin attempt to st...
# 12  in gotham city, batman stops a hostage situati...
# 13  charles foster kane, an enormously wealthy med...
# 14  li mu bai is an accomplished wudang swordsman....
# 15  in 1919, harold abrahams enters the university...
# 16  saloon owner kent, the unscrupulous boss of th...
# 17  kate miller is a sexually frustrated housewife...
# 19  the story is told from the viewpoint of lt. we...
# 20  five michigan state students venture into the ...
# 21  christine clay, a successful actress, argues p...
# 22  in a dystopian 1988, crime in the united state...
# 25  ash williams and his girlfriend linda take a r...
# 26  while taking a business trip, max klein surviv...
# 27  in the town of flklypa, the inventor reodor fe...
# 29  in the year 2065, a future earth is infested b...
# 30  the film tells the story of two girls, agnes a...
# 31  in 1967, during the vietnam war, a group of ne...
#
#                                              Synopsis
# 0   a man is accidentally transported to 1300 ad, ...
# 2   a blade runner must pursue and terminate four ...
# 5   an irish rogue wins the heart of a rich widow ...
# 6   a flighty teenage girl learns that she is her ...
# 7   when his secret bride is executed for assaulti...
# 8   the dark knight of gotham city begins his war ...
# 9   the caped crusader and his young ward battle e...
# 10  when a corrupt businessman and the grotesque p...
# 11  batman and robin try to keep their relationshi...
# 12  batman must battle former district attorney ha...
# 13  following the death of a publishing tycoon, ne...
# 14  a young chinese warrior steals a sword from a ...
# 15  two british track athletes, one a determined j...
# 16  when a tough western town needs taming, the mi...
# 17  a mysterious blonde woman kills one of a psych...
# 19  the claustrophobic world of a wwii german u bo...
# 20  five friends travel to a cabin in the woods, w...
# 21  a man on the run from a murder charge enlists ...
# 22  in 1997, when the us president crashes into ma...
# 25  the lone survivor of an onslaught of flesh pos...
# 26  a mans personality is dramatically changed aft...
# 27  reodor felgen decides that he will enter a car...
# 29  a scientist makes a last stand on earth with t...
# 30  two teenage girls in small town sweden elin is...
# 31  a pragmatic us marine observes the dehumanizin...

# %%
total = df.shape[0]
print('total instances from cleaned dataset:', total)
# Out:
# total instances from cleaned dataset: 19060

# %%
n = random.randint(0, total)
print(n)
print()
print(df['MoviePlot'].iloc[n])
print()
print(df['Synopsis'].iloc[n])
# Out:
# 16625
#
# in the early 1840s, wells fargo employee ramsay mackay comes upon a broken down carriage in the countryside and gives belle justine pryor and her mother a lift into buffalo, new york, though he warns them he is in a hurry to make a delivery of fresh oysters. the ladies endure a very bumpy ride, and he arrives in time to enable his employer, henry wells, to impress some bankers with the speed of his service. wells sends him to set up a branch office in st. louis, which is quite convenient, as the pryors reside there. mackay and justine begin seeing each other, though her mother disapproves, as does justines more socially prominent suitor, talbot carter. impressed with mackay, in 1846, wells sends him to open trails to california. mackay takes along hank york, a frontiersman who only works when he has to, and hanks constant indian companion, pawnee. among his many duties, mackay sets out to transport gold from a mining settlement to san francisco. one of his customers is prospector dan trimball. when dan expresses his longing for his sweetheart back east, mackay recommends wells fargos new shipping venture. elated, dan sends for his girl. meanwhile, when mackay sets out with the gold, he is shot and left for dead by two robbers. though he recovers, he is threatened by his miner customers, who do not believe he was robbed. fortunately, he shows them a draft from wells fargo that will cover all their losses. when mackay and dan meet the ship in san francisco in 1851, passenger henry wells has a surprise for his star employee justine has come too. the happy couple get married. though their union is strained at times by mackay being away so often on business, they have a daughter and remain in love. for the birth of their second child, justine sends her husband to fetch her mother. then comes the american civil war. the marriage is strained to the breaking point. desperately needed gold is sent repeatedly from the west to the union, but the shipments are intercepted. wells fargo is assigned the task of transporting 2,000,000 in gold. mackay, chosen to lead the wagon train, meets with president lincoln, who emphasizes to him how crucial this shipment is. however, justine and mrs. pryor are fervent southern supporters, and justines brother has been killed fighting for the confederacy. when mackay refuses justines plea to shirk his duty, she overhears the secret route he will take and writes it down. at the last moment, she crumples up the letter, but her mother has no such scruples. she passes the document along without her daughters knowledge. as a result, mackay is met by a confederate force led by talbot carter. mackay wins the battle, but both talbot and pawnee are killed. mackay finds the letter in his wifes handwriting among talbots possessions. when he returns to san francisco, his house is empty. his wife and two children have gone with his mother in law. many years later, mackay goes east for a dinner in his honor, he has an unexpected visitor afterward his now teenage daughter alice peggy stewart. she invites him to her seventeenth birthday party, but he declines, as he has to leave on business. however, he cannot stay away. when he enters, he sees his estranged wife and his heart softens. then he discovers that she was not responsible for the bloodshed, and they are fully reconciled.
#
# the life and career of a wells fargo official frames this fictionalized account of the express companys formation

# %% [markdown]
# ## Create Summaries for each summary

# %%
def augment_summarize(x):
    try:
        res = summarize(x)
        return res.replace('\n', ' ')
    except:
        return ""

# %%
df['MoviePlotSummary'] = df['MoviePlot'].apply(lambda x: augment_summarize(x))
df.head()
# Out:
#    MovieId                MovieTitle  Year  \
# 0     3217          army of darkness  1992
# 2     3746              blade runner  1982
# 5     4227              barry lyndon  1975
# 6     4231  buffy the vampire slayer  1992
# 7     4560                braveheart  1995
#
#                                            MoviePlot  \
# 0  after being pulled through a time portal, ash ...
# 2  hatnote in los angeles, november 2019, retired...
# 5  by what means redmond barry acquired the style...
# 6  buffy summers is introduced as a stereotypical...
# 7  in the 13th century, after several years of po...
#
#                                             Synopsis  \
# 0  a man is accidentally transported to 1300 ad, ...
# 2  a blade runner must pursue and terminate four ...
# 5  an irish rogue wins the heart of a rich widow ...
# 6  a flighty teenage girl learns that she is her ...
# 7  when his secret bride is executed for assaulti...
#
#                                     MoviePlotSummary
# 0  after being pulled through a time portal, ash ...
# 2  deckard watches a video of another blade runne...
# 5  nora and her family plan to relieve their pove...
# 6  meanwhile oliver pike, and best friend benny, ...
# 7  when he returns home, wallace falls in love wi...

# %% [markdown]
# # uncomment for summarized
# df = df[df['MoviePlotSummary'].str.len() > 10]
# total = df.shape[0]
# print("updated total:", total)

# %%
n = random.randint(0, df.shape[0])
print(df['MoviePlotSummary'].iloc[n])
print()
print(df['Synopsis'].iloc[n])
# Out:
# en route home after a day trip to the familys summer cottage with his father, timmy purchases a bouquet of roses and suggests john present them to his wife.
#
# a young man returning home from world war ii finds himself caught up in his parents turbulent relationship

# %% [markdown]
# ## Partition Dataset

# %%
training = int(0.95 * total)
print("training size:", training)
testing = total - training
print("total testing size:", testing)
test = int(testing/2)
print("test size:", test)
cv = total - training - test
print("cv size:", cv)
# Out:
# training size: 15014
# total testing size: 791
# test size: 395
# cv size: 396

# %%
s = random.sample(range(0, total-1), testing)
print("total len:", len(s))
for i in range(10):
    print(s[i])
# Out:
# total len: 791
# 12995
# 473
# 4761
# 13563
# 6383
# 10862
# 10171
# 1982
# 10480
# 12363

# %%
df_train = df.drop(df.index[s])
df_testing = df.iloc[s]
print(df_train.shape)
print(df_testing.shape)
# Out:
# (15014, 6)
# (791, 6)

# %%
t = random.sample(range(0, testing-1), test)
print("total len:", len(t))
for i in range(10):
    print(t[i])
# Out:
# total len: 395
# 159
# 377
# 653
# 63
# 671
# 691
# 10
# 273
# 674
# 767

# %%
df_test = df_testing.iloc[t]
df_cv = df_testing.drop(df_testing.index[t])

# %%
df_test.head()
# Out:
#         MovieId             MovieTitle  Year  \
# 9507    4451206              the hillz  2004
# 952      202133  the rules of the game  1939
# 16335  10722657                   kaun  1999
# 10884   5492073       deadly companion  1980
# 18661  13590180          magic kitchen  2004
#
#                                                MoviePlot  \
# 9507   the film follows the experiences of a promisin...
# 952    the film begins with the aviator andr jurieux ...
# 16335  in the malhotra household, a young woman is pr...
# 10884  michael taylor, played by michael sarrazin, is...
# 18661  yau became the proprietor and head chef of a s...
#
#                                                 Synopsis  \
# 9507   a promising college athlete takes a turn for t...
# 952    a bourgeois life in france at the onset of wor...
# 16335  while alone in the house, a woman hears news o...
# 10884  mentally tortured photojournalist attempts to ...
# 18661  yau is on the lookout for love in modern day h...
#
#                                         MoviePlotSummary
# 9507   after duff kills a kid who volunteers at the p...
# 952    he is greeted by his friend octave, who reveal...
# 16335  she is reluctant to open the door, even to tal...
# 10884  it is interesting to note that the cast of sct...
# 18661  yau cooks according to the large collection of...

# %%
df_cv.head()
# Out:
#         MovieId                             MovieTitle  Year  \
# 25416  24152307               bulldog drummond escapes  1937
# 7615    3257958  the santa clause 3: the escape clause  2006
# 10584   5274154                              storm boy  1976
# 20257  15945437                    cannibal apocalypse  1980
# 2923    1011144                      the farmer's wife  1928
#
#                                                MoviePlot  \
# 25416  captain high bulldog drummond has just returne...
# 7615   scott calvinsanta claus, and his wife, carol, ...
# 10584  storm boy likes to wander alone along the fier...
# 20257  the film opens with a flashback to the vietnam...
# 2923   tibby, the wife of samuel sweetland dies, and ...
#
#                                                 Synopsis  \
# 25416  captain drummond becomes a prisoner when he in...
# 7615   santa, aka scott calvin, is faced with double ...
# 10584  mike is a lonely australian boy living in a co...
# 20257  giovanni lambardo radice and john saxon are vi...
# 2923   after his daughter weds, a middle aged widower...
#
#                                         MoviePlotSummary
# 25416  as he goes to investigate, the woman drives aw...
# 7615   jack frost causes trouble for the family that ...
# 10584  after a pelican mother is shot, storm boy resc...
# 20257  the film opens with a flashback to the vietnam...
# 2923   tibby, the wife of samuel sweetland dies, and ...

# %%
df_train.head()
# Out:
#    MovieId                MovieTitle  Year  \
# 0     3217          army of darkness  1992
# 2     3746              blade runner  1982
# 5     4227              barry lyndon  1975
# 6     4231  buffy the vampire slayer  1992
# 7     4560                braveheart  1995
#
#                                            MoviePlot  \
# 0  after being pulled through a time portal, ash ...
# 2  hatnote in los angeles, november 2019, retired...
# 5  by what means redmond barry acquired the style...
# 6  buffy summers is introduced as a stereotypical...
# 7  in the 13th century, after several years of po...
#
#                                             Synopsis  \
# 0  a man is accidentally transported to 1300 ad, ...
# 2  a blade runner must pursue and terminate four ...
# 5  an irish rogue wins the heart of a rich widow ...
# 6  a flighty teenage girl learns that she is her ...
# 7  when his secret bride is executed for assaulti...
#
#                                     MoviePlotSummary
# 0  after being pulled through a time portal, ash ...
# 2  deckard watches a video of another blade runne...
# 5  nora and her family plan to relieve their pove...
# 6  meanwhile oliver pike, and best friend benny, ...
# 7  when he returns home, wallace falls in love wi...

# %%
print(df_train.shape[0])
print(df_test.shape[0])
print(df_cv.shape[0])
# Out:
# 15014
# 395
# 396

# %%
df.to_csv("./data/dataset.csv", sep='\t', encoding='utf-8', index=False)
df_train.to_csv("./data/train.csv", sep='\t', encoding='utf-8', index=False)
df_test.to_csv("./data/test.csv", sep='\t', encoding='utf-8', index=False)
df_cv.to_csv("./data/cv.csv", sep='\t', encoding='utf-8', index=False)
